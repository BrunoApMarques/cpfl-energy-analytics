# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carregar os dados tratados
df = pd.read_csv('../data/processed/interrupcoes_clean.csv')

df.head()
# Out:
#    id_ocorrencia        data_abertura      data_fechamento       regiao  \
# 0              1  2025-01-01 08:10:00  2025-01-01 10:20:00     Campinas
# 1              2  2025-01-02 14:35:00  2025-01-02 17:10:00       Sumaré
# 2              3  2025-01-03 09:00:00  2025-01-03 12:30:00   Indaiatuba
# 3              4  2025-01-04 11:15:00                  NaN     Campinas
# 4              5  2025-01-05 07:55:00  2025-01-05 08:40:00  Hortolândia
#
#          causa  clientes_afetados          status  duracao_min
# 0     Temporal                120       Concluída        130.0
# 1  Equipamento                 45       Concluída        155.0
# 2     Acidente                210       Concluída        210.0
# 3   Manutenção                 80  Em atendimento          0.0
# 4     Temporal                 30       Concluída         45.0

# %%
# Ocorrências por região
ocorrencias_regiao = df['regiao'].value_counts()

plt.figure(figsize=(10, 4))
ocorrencias_regiao.plot(kind='bar')
plt.title('Ocorrências por Região')
plt.xlabel('Região')
plt.ylabel('Quantidade de Ocorrências')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
# Ocorrências por Causa
ocorrencias_causa = df['causa'].value_counts()

plt.figure(figsize=(10, 4))
ocorrencias_causa.plot(kind='bar', color='orange')
plt.title('Ocorrências por Causa', fontsize=14)
plt.xlabel('Causa', fontsize=12)
plt.ylabel('Quantidade de Ocorrências', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
# Total de Clientes Afetados por Região
impacto_regiao = df.groupby('regiao')['clientes_afetados'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 4))
impacto_regiao.plot(kind='bar', color='green')
plt.title('Total de Clientes Afetados por Região', fontsize=14)
plt.xlabel('Região', fontsize=12)
plt.ylabel('Total de Clientes Afetados', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
# Duração Média por Região
duracao_media = df.groupby('regiao')['duracao_min'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 4))
duracao_media.plot(kind='bar', color='purple')
plt.title('Duração Média das Ocorrências por Região', fontsize=14)
plt.xlabel('Região', fontsize=12)
plt.ylabel('Duração Média (min)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
# Duração Média por Causa
duracao_por_causa = df.groupby('causa')['duracao_min'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 4))
duracao_por_causa.plot(kind='bar', color='red')
plt.title('Duração Média por Causa da Interrupção', fontsize=14)
plt.xlabel('Causa', fontsize=12)
plt.ylabel('Duração Média (min)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
# Duração Média por Status da Ocorrência
duracao_status = df.groupby('status')['duracao_min'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 4))
duracao_status.plot(kind='bar', color='teal')
plt.title('Duração Média por Status da Ocorrência', fontsize=14)
plt.xlabel('Status', fontsize=12)
plt.ylabel('Duração Média (min)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()
